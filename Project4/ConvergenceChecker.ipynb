# %%
import os

notebook_path = os.getcwd()
print(notebook_path)
# Out:
# C:\Users\thoma\PycharmProjects\IntroMachineLearning\Project4

# %%
import pandas as pd

higherPath = 'Smaller4LTrack/QLearning/13.08.2024_05.34.35_DF=0.99/historicalOutput.csv'
lowerPath = 'Smaller4LTrack/QLearning/13.08.2024_05.50.10_DF=0.9/historicalOutput.csv'
higherDataQ = pd.read_csv(higherPath, index_col=0)
lowerDataQ = pd.read_csv(lowerPath, index_col=0)

display(higherData)
# Out:
#     EpochNumber  SumOfValues
# 0           0.0     0.000000
# 0           1.0     0.000000
# 0           2.0     0.000000
# 0           3.0     2.000000
# 0           4.0     4.000000
# ..          ...          ...
# 0        4003.0  4255.189225
# 0        4004.0  4255.245000
# 0        4005.0  4255.266675
# 0        4006.0  4256.925155
# 0        4007.0  4257.025852
#
# [4008 rows x 2 columns]

# %%
import matplotlib.pyplot as plt



# Create the plot
plt.plot(higherDataQ['EpochNumber'], higherDataQ['SumOfValues'], label='.99')
plt.plot(lowerDataQ['EpochNumber'], lowerDataQ['SumOfValues'], label='.9')
# Add legend
plt.legend()
# Add title
plt.title('Tuning Discount Factor L Track Q Learning')

plt.show()

# %%
import pandas as pd

higherPath = 'Smaller4LTrack/SARSA/13.08.2024_06.23.35_DF=0.99/historicalOutput.csv'
lowerPath = 'Smaller4LTrack/SARSA/13.08.2024_07.32.05_DF=0.9/historicalOutput.csv'

higherDataSARSA = pd.read_csv(higherPath, index_col=0)
lowerDataSARSA = pd.read_csv(lowerPath, index_col=0)

display(higherData)
# Out:
#     EpochNumber  SumOfValues
# 0           0.0     0.000000
# 0           1.0     0.000000
# 0           2.0     0.000000
# 0           3.0     2.000000
# 0           4.0     4.000000
# ..          ...          ...
# 0        4003.0  4255.189225
# 0        4004.0  4255.245000
# 0        4005.0  4255.266675
# 0        4006.0  4256.925155
# 0        4007.0  4257.025852
#
# [4008 rows x 2 columns]

# %%
import matplotlib.pyplot as plt

# Create the plot
plt.plot(higherDataSARSA['EpochNumber'], higherDataSARSA['SumOfValues'], label='.99')
plt.plot(lowerDataSARSA['EpochNumber'], lowerDataSARSA['SumOfValues'], label='.9')
# Add lowerDataSARSA
plt.legend()
# Add title
plt.title('Tuning Discount Factor L Track SARSA')

plt.show()
