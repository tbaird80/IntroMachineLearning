# %%
getcwd()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21556\1272529679.py in <module>
# ----> 1 getcwd()
#
# NameError: name 'getcwd' is not defined

# %%
import pandas as pd

higherPath = '13.08.2024_05.34.35_DF=0.99/historicalOutput.csv'
lowerPath = '13.08.2024_05.34.35_DF=0.99/historicalOutput.csv'

higherData = pd.read_csv(higherPath, index_col=0)
lowerData = pd.read_csv(lowerPath, index_col=0)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21556\622112776.py in <module>
#       4 lowerPath = '13.08.2024_05.34.35_DF=0.99/historicalOutput.csv'
#       5
# ----> 6 higherData = pd.read_csv(higherPath, index_col=0)
#       7 lowerData = pd.read_csv(lowerPath, index_col=0)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
display(

# %%
import matplotlib.pyplot as plt



# Create the plot
plt.plot(higherData['EpochNumber'], higherData['SumOfValues'])
plt.xlabel('EpochNumber')
plt.ylabel('TotalLearning')
plt.title('Sample Plot')

# Create the plot
plt.plot(lowerData['EpochNumber'], lowerData['SumOfValues'])
plt.xlabel('EpochNumber')
plt.ylabel('TotalLearning')
plt.title('Sample Plot')
# Out:
# Text(0.5, 1.0, 'Sample Plot')
